# %%
# %cd ..
# Out:
# /home1/giorgian/projects/trigger-detection-pipeline/sPHENIX/trigger-detection/BGN-ST

# %%
import numpy as np
import glob
from dataloaders.pred_tracks import load_graph
import os
import matplotlib.pyplot as plt

# %%
DIR = '/ssd1/giorgian/pileup-sweep-1/prime-sweep-27/trigger/1/'

# %%
files = glob.glob(os.path.join(DIR, '*.npz'))

# %%
f = np.load(files[0])

# %%
plt.scatter(f['hit_cartesian'][:, 0], f['hit_cartesian'][:, 1])
plt.xlim(-10, 10)
plt.ylim(-10, 10)
# Out:
# (-10.0, 10.0)

# %%
e = load_graph(files[0], 0.9, intt_required=True)

# %%
hits = e.track_hits.reshape(-1, 3)

# %%
plt.scatter(hits[:, 0], hits[:, 1])
plt.xlim(-10, 10)
plt.ylim(-10, 10)
# Out:
# (-10.0, 10.0)
