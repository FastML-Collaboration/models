# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
f = np.load('/ssd2/tingting/HFMLNewFiles-old-parsed-hits/trigger/1/event100000021.npz')

# %%
hits = f['hits_xyz']
pids = f['pid']

# %%
np.unique(pids, return_counts=True)
# Out:
# (array([-219, -136, -135,  -55,   -1,    5,    6,    7,    8,   54,   56,
#           57,   58,   63,   64,   73,   74,   75,   77,   81,   83,   84,
#           85,   86,   89,   90]),
#  array([ 4,  4,  3,  4, 33,  5,  5,  5,  5,  5,  5,  4,  5,  5,  4,  5,  4,
#          4,  5,  5,  4,  5,  5, 44,  3,  5]))

# %%
len(set(pids))
# Out:
# 26

# %%
plt.scatter(hits[:, 0], hits[:, 1])#, c=pids/max(pids)*255)

# %%
plt.scatter(hits[:, 0][pids == 86], hits[:, 1][pids == 86])#, c=pids/max(pids)*255)
